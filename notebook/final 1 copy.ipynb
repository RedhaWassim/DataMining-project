# %% [markdown]
# # IMPORT

# %%
import pandas as pd
from soil_fertility.components.data_ingestion import DataIngestion
from soil_fertility.components.data_transformation.data_transformation import DataTransformation

import warnings
warnings.filterwarnings('ignore')
from pathlib import Path

# %% [markdown]
# # INGESTION

# %%
data_path="/home/redha/Documents/projects/NLP/datamining project/Soil-Fertility/data/Dataset1.csv"

# %%
obj = DataIngestion()
part,train_path,test_path= obj.init_ingestion(
    data_path
)

# %%
print("part : ",part)
print("train_path : ",Path(train_path))
print("test_path : ",Path(test_path))
# Out:
# part :  1
# train_path :  /home/redha/Documents/projects/NLP/datamining project/Soil-Fertility/artifacts/raw/1/train.csv
# test_path :  /home/redha/Documents/projects/NLP/datamining project/Soil-Fertility/artifacts/raw/1/test.csv

# %% [markdown]
# # Analysis

# %%
train_df=pd.read_csv(train_path)
test_df=pd.read_csv(test_path)
df = pd.concat([train_df, test_df], ignore_index=True)

# %%
df
# Out:
#        N      P    K    pH    EC    OC      S    Zn    Fe    Cu     Mn     B  \
# 0    333    6.6  729  7.20  0.31  0.38   7.10  0.24  2.94  0.83   7.63  0.15
# 1    301  111.8  486  7.50  0.54  0.43   6.50  0.25  1.57  0.23  18.71  0.35
# 2    339    5.7  697  8.00  0.65  0.68   8.75  0.32  6.25  1.85  15.47  0.42
# 3    213   10.7  771  7.29  0.52  0.68   5.73  0.49  8.51  0.75  15.62  0.36
# 4    333   14.3  507  7.43  0.61  0.88   7.24  0.37  1.26  1.37  12.03  0.29
# ..   ...    ...  ...   ...   ...   ...    ...   ...   ...   ...    ...   ...
# 873  276   11.2  475  7.50  0.35  0.39   4.52  0.52  6.32  0.54   8.62  0.34
# 874  238    5.7  454  7.61  0.62  1.09   3.50  0.34  2.56  1.10   7.36  0.14
# 875  264    7.2  370  7.68  0.66  1.27  10.56  0.60  6.52  1.57  11.05  0.40
# 876  270    5.0  602  7.00  0.36  0.39  10.56  0.32  3.54  1.47  11.57  0.67
# 877   69    8.1  338  7.50  0.63  0.78   8.40  0.37  2.12  1.03   2.84  2.26
#
#          OM  Fertility
# 0    0.6536          1
# 1    0.7396          1
# 2    1.1696          1
# 3    1.1696          0
# 4    1.5136          2
# ..      ...        ...
# 873  0.6708          1
# 874  1.8748          0
# 875  2.1844          0
# 876  0.6708          0
# 877  1.3416          0
#
# [878 rows x 14 columns]

# %%
df.describe()
# Out:
#                 N           P            K          pH          EC  \
# count  878.000000  878.000000   878.000000  878.000000  878.000000
# mean   246.842825   14.572437   501.042141    7.510706    0.544077
# std     77.370500   21.991113   129.100764    0.464720    0.141563
# min      6.000000    2.900000    11.000000    0.900000    0.100000
# 25%    201.000000    6.800000   412.000000    7.350000    0.430000
# 50%    257.000000    8.100000   475.000000    7.500000    0.550000
# 75%    307.000000   10.650000   581.000000    7.630000    0.640000
# max    383.000000  125.000000  1560.000000   11.150000    0.950000
#
#                OC           S          Zn          Fe          Cu         Mn  \
# count  878.000000  878.000000  878.000000  878.000000  878.000000  878.00000
# mean     0.617665    7.525239    0.469419    4.145763    0.951697    8.68836
# std      0.843975    4.405285    1.896323    3.107853    0.466295    4.29319
# min      0.100000    0.640000    0.070000    0.210000    0.090000    0.11000
# 25%      0.380000    4.700000    0.280000    2.060000    0.630000    6.23000
# 50%      0.590000    6.640000    0.360000    3.565000    0.930000    8.36500
# 75%      0.780000    8.750000    0.470000    6.320000    1.250000   11.48000
# max     24.000000   31.000000   42.000000   44.000000    3.020000   31.00000
#
#                 B          OM   Fertility
# count  878.000000  878.000000  878.000000
# mean     0.586139    1.062384    0.587699
# std      0.564529    1.451637    0.573798
# min      0.060000    0.172000    0.000000
# 25%      0.270000    0.653600    0.000000
# 50%      0.400000    1.014800    1.000000
# 75%      0.610000    1.341600    1.000000
# max      2.820000   41.280000    2.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 878 entries, 0 to 877
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   N          878 non-null    int64
#  1   P          878 non-null    float64
#  2   K          878 non-null    int64
#  3   pH         878 non-null    float64
#  4   EC         878 non-null    float64
#  5   OC         878 non-null    float64
#  6   S          878 non-null    float64
#  7   Zn         878 non-null    float64
#  8   Fe         878 non-null    float64
#  9   Cu         878 non-null    float64
#  10  Mn         878 non-null    float64
#  11  B          878 non-null    float64
#  12  OM         878 non-null    float64
#  13  Fertility  878 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 96.2 KB

# %% [markdown]
# # Transformation

# %%
tranformation_obj = DataTransformation()
part,preprocessor,processed_train_path,processed_test_path = tranformation_obj.transform(
    train_path,test_path,target="Fertility"
)
# Out:
# train_coolumns=  Index(['N', 'P', 'K', 'pH', 'EC', 'OC', 'S', 'Zn', 'Fe', 'Cu', 'Mn', 'B', 'OM',
#        'Fertility'],
#       dtype='object')
# test_coolumns=  Index(['N', 'P', 'K', 'pH', 'EC', 'OC', 'S', 'Zn', 'Fe', 'Cu', 'Mn', 'B', 'OM',
#        'Fertility'],
#       dtype='object')
# train_coolumns=  Index(['N', 'P', 'K', 'pH', 'EC', 'OC', 'S', 'Zn', 'Fe', 'Cu', 'Mn', 'B', 'OM',
#        'Fertility'],
#       dtype='object')
# test_coolumns=  Index(['N', 'P', 'K', 'pH', 'EC', 'OC', 'S', 'Zn', 'Fe', 'Cu', 'Mn', 'B', 'OM',
#        'Fertility'],
#       dtype='object')

# %%
print(preprocessor)
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('numerical',
#                                  Pipeline(steps=[('imputer',
#                                                   MinMaxTransformation())]),
#                                  Index(['N', 'P', 'K', 'pH', 'EC', 'OC', 'S', 'Zn', 'Fe', 'Cu', 'Mn', 'B',
#        'OM'],
#       dtype='object'))])

# %%
print("part : ",part)
print("processed_train_path : ",Path(processed_train_path))
print("processed_test_path : ",Path(processed_test_path))
# Out:
# part :  1
# processed_train_path :  /home/redha/Documents/projects/NLP/datamining project/Soil-Fertility/artifacts/intermediate/1/train.csv
# processed_test_path :  /home/redha/Documents/projects/NLP/datamining project/Soil-Fertility/artifacts/intermediate/1/test.csv

# %%
df
# Out:
#        N      P    K    pH    EC    OC      S    Zn    Fe    Cu     Mn     B  \
# 0    333    6.6  729  7.20  0.31  0.38   7.10  0.24  2.94  0.83   7.63  0.15
# 1    301  111.8  486  7.50  0.54  0.43   6.50  0.25  1.57  0.23  18.71  0.35
# 2    339    5.7  697  8.00  0.65  0.68   8.75  0.32  6.25  1.85  15.47  0.42
# 3    213   10.7  771  7.29  0.52  0.68   5.73  0.49  8.51  0.75  15.62  0.36
# 4    333   14.3  507  7.43  0.61  0.88   7.24  0.37  1.26  1.37  12.03  0.29
# ..   ...    ...  ...   ...   ...   ...    ...   ...   ...   ...    ...   ...
# 873  276   11.2  475  7.50  0.35  0.39   4.52  0.52  6.32  0.54   8.62  0.34
# 874  238    5.7  454  7.61  0.62  1.09   3.50  0.34  2.56  1.10   7.36  0.14
# 875  264    7.2  370  7.68  0.66  1.27  10.56  0.60  6.52  1.57  11.05  0.40
# 876  270    5.0  602  7.00  0.36  0.39  10.56  0.32  3.54  1.47  11.57  0.67
# 877   69    8.1  338  7.50  0.63  0.78   8.40  0.37  2.12  1.03   2.84  2.26
#
#          OM  Fertility
# 0    0.6536          1
# 1    0.7396          1
# 2    1.1696          1
# 3    1.1696          0
# 4    1.5136          2
# ..      ...        ...
# 873  0.6708          1
# 874  1.8748          0
# 875  2.1844          0
# 876  0.6708          0
# 877  1.3416          0
#
# [878 rows x 14 columns]

# %%
train_df=pd.read_csv(processed_train_path)
test_df=pd.read_csv(processed_test_path)

# %%
names=list(df.columns)
train_df = train_df.rename(columns=dict(zip(train_df.columns, names)))
test_df = test_df.rename(columns=dict(zip(test_df.columns, names)))

# %%
train_df
# Out:
#             N         P         K        pH        EC        OC         S  \
# 0    0.867374  0.030303  0.463525  0.614634  0.150685  0.011715  0.231044
# 1    0.782493  0.891892  0.306649  0.643902  0.465753  0.013808  0.209585
# 2    0.883289  0.022932  0.442866  0.692683  0.616438  0.024268  0.290057
# 3    0.549072  0.063882  0.490639  0.623415  0.438356  0.024268  0.182046
# 4    0.867374  0.093366  0.320207  0.637073  0.561644  0.032636  0.236052
# ..        ...       ...       ...       ...       ...       ...       ...
# 697  0.416446  0.042588  0.313105  0.643902  0.780822  0.044770  0.203505
# 698  0.450928  0.046683  0.320207  0.660488  0.520548  0.028870  0.148784
# 699  0.816976  0.060606  0.429309  0.598049  0.260274  0.040586  0.171316
# 700  0.949602  0.042588  0.306649  0.639024  0.397260  0.000000  0.311516
# 701  0.533156  0.031941  0.204003  0.653659  0.698630  0.024268  0.257511
#
#            Zn        Fe        Cu        Mn         B        OM  Fertility
# 0    0.004482  0.080793  0.252560  0.239753  0.032609  0.011715          1
# 1    0.004746  0.040249  0.047782  0.600195  0.105072  0.013808          1
# 2    0.006591  0.178751  0.600683  0.494795  0.130435  0.024268          1
# 3    0.011073  0.245635  0.225256  0.499675  0.108696  0.024268          0
# 4    0.007909  0.031074  0.436860  0.382889  0.083333  0.032636          2
# ..        ...       ...       ...       ...       ...       ...        ...
# 697  0.011600  0.172240  0.419795  0.239753  0.123188  0.044770          0
# 698  0.005273  0.099142  0.187713  0.177944  0.010870  0.028870          0
# 699  0.008437  0.178159  0.129693  0.079050  0.159420  0.040586          1
# 700  0.007382  0.204498  0.303754  0.236825  0.159420  0.000000          1
# 701  0.013182  0.112755  0.395904  0.197137  0.061594  0.024268          0
#
# [702 rows x 14 columns]

# %%
test_df
# Out:
#             N         P         K        pH        EC        OC         S  \
# 0    0.615385  0.008190  0.245320  0.653659  0.506849  0.000000  0.290057
# 1    0.501326  0.031941  0.245320  0.641951  0.232877  0.002092  0.102289
# 2    0.716180  0.081900  0.251775  0.629268  0.890411  0.024268  0.117310
# 3    0.915119  0.096642  0.238218  0.682927  0.315068  0.028452  0.117310
# 4    0.533156  0.039312  0.238218  0.657561  0.643836  0.006695  0.127325
# ..        ...       ...       ...       ...       ...       ...       ...
# 171  0.716180  0.067977  0.299548  0.643902  0.205479  0.012134  0.138770
# 172  0.615385  0.022932  0.285991  0.654634  0.575342  0.041423  0.102289
# 173  0.684350  0.035217  0.231762  0.661463  0.630137  0.048954  0.354793
# 174  0.700265  0.017199  0.381536  0.595122  0.219178  0.012134  0.354793
# 175  0.167109  0.042588  0.211104  0.643902  0.589041  0.028452  0.277539
#
#            Zn        Fe        Cu        Mn         B        OM  Fertility
# 0    0.011600  0.057413  0.184300  0.432010  0.199275  0.000000          0
# 1    0.004218  0.069547  0.180887  0.230644  0.014493  0.002092          0
# 2    0.003955  0.083161  0.406143  0.453806  0.130435  0.024268          1
# 3    0.005273  0.112755  0.597270  0.294730  0.083333  0.028452          1
# 4    0.005009  0.110092  0.201365  0.279440  0.076087  0.006695          0
# ..        ...       ...       ...       ...       ...       ...        ...
# 171  0.011864  0.180823  0.153584  0.271958  0.101449  0.012134          1
# 172  0.007118  0.069547  0.344710  0.230969  0.028986  0.041423          0
# 173  0.013973  0.186742  0.505119  0.351008  0.123188  0.048954          0
# 174  0.006591  0.098550  0.470990  0.367925  0.221014  0.012134          0
# 175  0.007909  0.056526  0.320819  0.083930  0.797101  0.028452          0
#
# [176 rows x 14 columns]

# %%
from soil_fertility.components.models.decision_tree import DecisionTree
from soil_fertility.components.models.random_forest import RandomForest

# %%
target_column = "Fertility"
X_train = train_df.drop(columns=[target_column]).to_numpy()
y_train = train_df[target_column].to_numpy()
X_test = test_df.drop(columns=[target_column]).to_numpy()
y_test = test_df[target_column].to_numpy()

# %%
from soil_fertility.components.model_trainer import ModelTrainer

# %%
model_trainer=ModelTrainer()
result=  model_trainer.init_training(train_data=train_df,
                                     test_data=test_df,
                                     target_column="Fertility",
                                     mode="default")

# %%
result
# Out:
# {'metrics': {'decision_tree': {'accuracy': 0.8693181818181818,
#    'confusion_matrix': [[64, 6], [11, 87]],
#    'recall': 0.8529411764705882,
#    'precision': 0.925531914893617,
#    'f1_score': 0.8877551020408163,
#    'specificite': 0.9142857142857143,
#    'metrics_per_class': {0: {'precision': 0.8421052631578947,
#      'recall': 0.9142857142857143,
#      'f1_score': 0.8767123287671234},
#     1: {'precision': 0.925531914893617,
#      'recall': 0.8529411764705882,
#      'f1_score': 0.8877551020408163},
#     2: {'precision': 0.3333333333333333, 'recall': 0.5, 'f1_score': 0.4}},
#    'specificity_per_class': {0: 0.8867924528301887,
#     1: 0.9054054054054054,
#     2: 0.9767441860465116}},
#   'random_forest': {'accuracy': 0.4318181818181818,
#    'confusion_matrix': [[67, 3], [93, 9]],
#    'recall': 0.08823529411764706,
#    'precision': 0.6428571428571429,
#    'f1_score': 0.15517241379310345,
#    'specificite': 0.9571428571428572,
#    'metrics_per_class': {0: {'precision': 0.41358024691358025,
#      'recall': 0.9571428571428572,
#      'f1_score': 0.5775862068965518},
#     1: {'precision': 0.6428571428571429,
#      'recall': 0.08823529411764706,
#      'f1_score': 0.15517241379310345},
#     2: {'precision': 0, 'recall': 0.0, 'f1_score': 0}},
#    'specificity_per_class': {0: 0.10377358490566038,
#     1: 0.9324324324324325,
#     2: 1.0}}},
#  'decision_tree': <soil_fertility.components.models.decision_tree.DecisionTree at 0x7f01a4e032e0>,
#  'random_forest': <soil_fertility.components.models.random_forest.RandomForest at 0x7f01a4e00eb0>}

# %%
model_trainer2=ModelTrainer()
result2=  model_trainer.init_training(train_data=train_df,
                                     test_data=test_df,
                                     target_column="Fertility",
                                     mode="gridsearch")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[66], line 2
#       1 model_trainer2=ModelTrainer()
# ----> 2 result2=  model_trainer.init_training(train_data=train_df,
#       3                                      test_data=test_df,
#       4                                      target_column="Fertility",
#       5                                      mode="gridsearch")
#
# File ~/Documents/projects/NLP/datamining project/Soil-Fertility/soil_fertility/components/model_trainer.py:59, in ModelTrainer.init_training(self, train_data, test_data, target_column, mode)
#      54     model_report: dict = evaluate_model(
#      55         X_train, y_train, X_test, y_test, models
#      56     )
#      58 elif mode == "gridsearch":
# ---> 59     model_report: dict = evaluate_model_gridseach(
#      60         X_train, y_train, X_test, y_test, models, params=params
#      61     )
#      63 else:
#      64     logging.error("Mode not supported , please use default or grid_search")
#
# File ~/Documents/projects/NLP/datamining project/Soil-Fertility/soil_fertility/components/model_utils.py:83, in evaluate_model_gridseach(X_train, y_train, X_test, y_test, models, params)
#      81 model_name = list(models.keys())[i]
#      82 para = params[list(models.keys())[i]]
# ---> 83 grid_search = GridSearchCV(model, para, cv=5, scoring="accuracy")
#      84 grid_search.fit(X_train, y_train)
#      87 y_train_pred = grid_search.predict(X_train)
#
# File ~/Documents/projects/NLP/datamining project/Soil-Fertility/.venv/lib/python3.10/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~/Documents/projects/NLP/datamining project/Soil-Fertility/.venv/lib/python3.10/site-packages/sklearn/model_selection/_search.py:898, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     892     results = self._format_results(
#     893         all_candidate_params, n_splits, all_out, all_more_results
#     894     )
#     896     return results
# --> 898 self._run_search(evaluate_candidates)
#     900 # multimetric is determined here because in the case of a callable
#     901 # self.scoring the return type is only known after calling
#     902 first_test_score = all_out[0]["test_scores"]
#
# File ~/Documents/projects/NLP/datamining project/Soil-Fertility/.venv/lib/python3.10/site-packages/sklearn/model_selection/_search.py:1422, in GridSearchCV._run_search(self, evaluate_candidates)
#    1420 def _run_search(self, evaluate_candidates):
#    1421     """Search all candidates in param_grid"""
# -> 1422     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/Documents/projects/NLP/datamining project/Soil-Fertility/.venv/lib/python3.10/site-packages/sklearn/model_selection/_search.py:845, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     837 if self.verbose > 0:
#     838     print(
#     839         "Fitting {0} folds for each of {1} candidates,"
#     840         " totalling {2} fits".format(
#     841             n_splits, n_candidates, n_candidates * n_splits
#     842         )
#     843     )
# --> 845 out = parallel(
#     846     delayed(_fit_and_score)(
#     847         clone(base_estimator),
#     848         X,
#     849         y,
#     850         train=train,
#     851         test=test,
#     852         parameters=parameters,
#     853         split_progress=(split_idx, n_splits),
#     854         candidate_progress=(cand_idx, n_candidates),
#     855         **fit_and_score_kwargs,
#     856     )
#     857     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     858         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     859     )
#     860 )
#     862 if len(out) < 1:
#     863     raise ValueError(
#     864         "No fits were performed. "
#     865         "Was the CV iterator empty? "
#     866         "Were there no candidates?"
#     867     )
#
# File ~/Documents/projects/NLP/datamining project/Soil-Fertility/.venv/lib/python3.10/site-packages/sklearn/utils/parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File ~/Documents/projects/NLP/datamining project/Soil-Fertility/.venv/lib/python3.10/site-packages/joblib/parallel.py:1863, in Parallel.__call__(self, iterable)
#    1861     output = self._get_sequential_output(iterable)
#    1862     next(output)
# -> 1863     return output if self.return_generator else list(output)
#    1865 # Let's create an ID that uniquely identifies the current call. If the
#    1866 # call is interrupted early and that the same instance is immediately
#    1867 # re-used, this id will be used to prevent workers that were
#    1868 # concurrently finalizing a task from the previous call to run the
#    1869 # callback.
#    1870 with self._lock:
#
# File ~/Documents/projects/NLP/datamining project/Soil-Fertility/.venv/lib/python3.10/site-packages/joblib/parallel.py:1792, in Parallel._get_sequential_output(self, iterable)
#    1790 self.n_dispatched_batches += 1
#    1791 self.n_dispatched_tasks += 1
# -> 1792 res = func(*args, **kwargs)
#    1793 self.n_completed_tasks += 1
#    1794 self.print_progress()
#
# File ~/Documents/projects/NLP/datamining project/Soil-Fertility/.venv/lib/python3.10/site-packages/sklearn/utils/parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File ~/Documents/projects/NLP/datamining project/Soil-Fertility/.venv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:729, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     727         estimator.fit(X_train, **fit_params)
#     728     else:
# --> 729         estimator.fit(X_train, y_train, **fit_params)
#     731 except Exception:
#     732     # Note fit time as time until error
#     733     fit_time = time.time() - start_time
#
# File ~/Documents/projects/NLP/datamining project/Soil-Fertility/soil_fertility/components/models/random_forest.py:30, in RandomForest.fit(self, X, y, feature_names)
#      28 # Train a Decision Tree on the bootstrapped data
#      29 tree = DecisionTree(max_depth=self.max_depth)
# ---> 30 tree.fit(X_bootstrap, y_bootstrap, feature_names=self.feature_names)
#      31 self.trees.append(tree)
#
# File ~/Documents/projects/NLP/datamining project/Soil-Fertility/soil_fertility/components/models/decision_tree.py:10, in DecisionTree.fit(self, X, y, feature_names)
#       8 def fit(self, X, y, feature_names=None):
#       9     self.feature_names = feature_names
# ---> 10     self.tree = self._build_tree(X, y, depth=0)
#
# File ~/Documents/projects/NLP/datamining project/Soil-Fertility/soil_fertility/components/models/decision_tree.py:40, in DecisionTree._build_tree(self, X, y, depth)
#      37 right_mask = ~left_mask
#      39 # Recursively build the left and right subtrees
# ---> 40 left_subtree = self._build_tree(X[left_mask], y[left_mask], depth + 1)
#      41 right_subtree = self._build_tree(X[right_mask], y[right_mask], depth + 1)
#      43 # Return the decision node
#
# File ~/Documents/projects/NLP/datamining project/Soil-Fertility/soil_fertility/components/models/decision_tree.py:41, in _build_tree(self, X, y, depth)
#      38 right_mask = ~left_mask
#      40 # Recursively build the left and right subtrees
# ---> 41 left_subtree = self._build_tree(X[left_mask], y[left_mask], depth + 1)
#      42 right_subtree = self._build_tree(X[right_mask], y[right_mask], depth + 1)
#      44 # Return the decision node
#
# File ~/Documents/projects/NLP/datamining project/Soil-Fertility/soil_fertility/components/models/decision_tree.py:41, in _build_tree(self, X, y, depth)
#      38 right_mask = ~left_mask
#      40 # Recursively build the left and right subtrees
# ---> 41 left_subtree = self._build_tree(X[left_mask], y[left_mask], depth + 1)
#      42 right_subtree = self._build_tree(X[right_mask], y[right_mask], depth + 1)
#      44 # Return the decision node
#
#     [... skipping similar frames: _build_tree at line 41 (1 times)]
#
# File ~/Documents/projects/NLP/datamining project/Soil-Fertility/soil_fertility/components/models/decision_tree.py:41, in _build_tree(self, X, y, depth)
#      38 right_mask = ~left_mask
#      40 # Recursively build the left and right subtrees
# ---> 41 left_subtree = self._build_tree(X[left_mask], y[left_mask], depth + 1)
#      42 right_subtree = self._build_tree(X[right_mask], y[right_mask], depth + 1)
#      44 # Return the decision node
#
# File ~/Documents/projects/NLP/datamining project/Soil-Fertility/soil_fertility/components/models/decision_tree.py:40, in DecisionTree._build_tree(self, X, y, depth)
#      37 right_mask = ~left_mask
#      39 # Recursively build the left and right subtrees
# ---> 40 left_subtree = self._build_tree(X[left_mask], y[left_mask], depth + 1)
#      41 right_subtree = self._build_tree(X[right_mask], y[right_mask], depth + 1)
#      43 # Return the decision node
#
# File ~/Documents/projects/NLP/datamining project/Soil-Fertility/soil_fertility/components/models/decision_tree.py:28, in DecisionTree._build_tree(self, X, y, depth)
#      25     return {"class": majority_class, "count": counts[np.argmax(counts)]}
#      27 # Choose the best attribute to split on
# ---> 28 best_attribute, best_threshold = self._find_best_split(X, y)
#      30 # If no useful split found, return a leaf node with the majority class
#      31 if best_attribute is None:
#
# File ~/Documents/projects/NLP/datamining project/Soil-Fertility/soil_fertility/components/models/decision_tree.py:66, in DecisionTree._find_best_split(self, X, y)
#      63 right_mask = ~left_mask
#      65 if np.sum(left_mask) > 0 and np.sum(right_mask) > 0:
# ---> 66     information_gain = self._calculate_information_gain(
#      67         y, left_mask, right_mask
#      68     )
#      70     if information_gain > best_information_gain:
#      71         best_information_gain = information_gain
#
# File ~/Documents/projects/NLP/datamining project/Soil-Fertility/soil_fertility/components/models/decision_tree.py:78, in _calculate_information_gain(self, y, left_mask, right_mask)
#      74                     best_threshold = threshold
#      76     return best_attribute, best_threshold
# ---> 78 def _calculate_information_gain(self, y, left_mask, right_mask):
#      79     total_entropy = self._calculate_entropy(y)
#      81     left_entropy = self._calculate_entropy(y[left_mask])
#
# File ~/Documents/projects/NLP/datamining project/Soil-Fertility/soil_fertility/components/models/decision_tree.py:94, in DecisionTree._calculate_entropy(self, y)
#      93 def _calculate_entropy(self, y):
# ---> 94     _, counts = np.unique(y, return_counts=True)
#      95     probabilities = counts / len(y)
#      96     entropy = -np.sum(probabilities * np.log2(probabilities + 1e-10))
#
# File ~/Documents/projects/NLP/datamining project/Soil-Fertility/.venv/lib/python3.10/site-packages/numpy/lib/arraysetops.py:276, in unique(ar, return_index, return_inverse, return_counts, axis, equal_nan)
#     273 if axis is None:
#     274     ret = _unique1d(ar, return_index, return_inverse, return_counts,
#     275                     equal_nan=equal_nan)
# --> 276     return _unpack_tuple(ret)
#     278 # axis was specified and not None
#     279 try:
#
# File ~/Documents/projects/NLP/datamining project/Soil-Fertility/.venv/lib/python3.10/site-packages/numpy/lib/arraysetops.py:125, in _unpack_tuple(x)
#     121     np.subtract(ary[1:], ary[:-1], result[l_begin:l_begin + l_diff])
#     122     return result
# --> 125 def _unpack_tuple(x):
#     126     """ Unpacks one-element tuples for use as return values """
#     127     if len(x) == 1:
#
# KeyboardInterrupt:

# %%
result2
