# %%
from soil_fertility.components.transformations import DropMissingValues,DropDuplicates,CustomImputer,MinMaxTransformation,ZScoreTransformation
import numpy as np

# %%
import pandas as pd

# Load data
df = pd.read_csv('/home/redha/Documents/projects/NLP/datamining project/Soil-Fertility/data/Dataset1.csv')

# %%
df
# Out:
#        N     P    K    pH    EC    OC      S    Zn    Fe    Cu     Mn     B  \
# 0    138   8.6  560  7.46  0.62  0.70   5.90  0.24  0.31  0.77   8.71  0.11
# 1    213   7.5  338  7.62  0.75  1.06  25.40  0.30  0.86  1.54   2.89  2.29
# 2    163   9.6  718  7.59  0.51  1.11  14.30  0.30  0.86  1.57   2.70  2.03
# 3    157   6.8  475  7.64  0.58  0.94  26.00  0.34  0.54  1.53   2.65  1.82
# 4    270   9.9  444  7.63  0.40  0.86  11.80  0.25  0.76  1.69   2.43  2.26
# ..   ...   ...  ...   ...   ...   ...    ...   ...   ...   ...    ...   ...
# 880  276   9.2  370  7.62  0.62  0.49   6.64  0.42  3.57  0.63   6.48  0.32
# 881  320  13.8  391  7.38  0.65  1.07   5.43  0.58  4.58  1.02  13.25  0.53
# 882  264  10.3  475  7.49  0.74  0.88  10.56  0.45  7.36  1.87  10.63  0.63
# 883  220   8.6  444  7.43  0.65  0.72  11.70  0.37  0.66  0.90   2.19  1.82
# 884  270   8.1  655  7.45  0.55  0.67  10.20  0.28  0.44  1.26   7.75  2.56
#
#          OM  Fertility
# 0    1.2040          0
# ...

# %%
dropper=DropMissingValues()
df=dropper.fit_transform(df)

# %%
df
# Out:
#        N     P    K    pH    EC    OC      S    Zn    Fe    Cu     Mn     B  \
# 0    138   8.6  560  7.46  0.62  0.70   5.90  0.24  0.31  0.77   8.71  0.11
# 1    213   7.5  338  7.62  0.75  1.06  25.40  0.30  0.86  1.54   2.89  2.29
# 2    163   9.6  718  7.59  0.51  1.11  14.30  0.30  0.86  1.57   2.70  2.03
# 3    157   6.8  475  7.64  0.58  0.94  26.00  0.34  0.54  1.53   2.65  1.82
# 4    270   9.9  444  7.63  0.40  0.86  11.80  0.25  0.76  1.69   2.43  2.26
# ..   ...   ...  ...   ...   ...   ...    ...   ...   ...   ...    ...   ...
# 880  276   9.2  370  7.62  0.62  0.49   6.64  0.42  3.57  0.63   6.48  0.32
# 881  320  13.8  391  7.38  0.65  1.07   5.43  0.58  4.58  1.02  13.25  0.53
# 882  264  10.3  475  7.49  0.74  0.88  10.56  0.45  7.36  1.87  10.63  0.63
# 883  220   8.6  444  7.43  0.65  0.72  11.70  0.37  0.66  0.90   2.19  1.82
# 884  270   8.1  655  7.45  0.55  0.67  10.20  0.28  0.44  1.26   7.75  2.56
#
#          OM  Fertility
# 0    1.2040          0
# ...

# %%
duplcate_remover=DropDuplicates()
df=duplcate_remover.fit_transform(df)

# %%
df
# Out:
#        N     P    K    pH    EC    OC      S    Zn    Fe    Cu     Mn     B  \
# 0    138   8.6  560  7.46  0.62  0.70   5.90  0.24  0.31  0.77   8.71  0.11
# 1    213   7.5  338  7.62  0.75  1.06  25.40  0.30  0.86  1.54   2.89  2.29
# 2    163   9.6  718  7.59  0.51  1.11  14.30  0.30  0.86  1.57   2.70  2.03
# 3    157   6.8  475  7.64  0.58  0.94  26.00  0.34  0.54  1.53   2.65  1.82
# 4    270   9.9  444  7.63  0.40  0.86  11.80  0.25  0.76  1.69   2.43  2.26
# ..   ...   ...  ...   ...   ...   ...    ...   ...   ...   ...    ...   ...
# 878  351  10.7  623  7.96  0.51  0.29   7.24  0.36  4.69  0.69  11.03  0.69
# 879  264   9.0  486  7.24  0.47  0.10   3.92  0.35  8.26  0.45   7.98  0.40
# 880  276   9.2  370  7.62  0.62  0.49   6.64  0.42  3.57  0.63   6.48  0.32
# 881  320  13.8  391  7.38  0.65  1.07   5.43  0.58  4.58  1.02  13.25  0.53
# 882  264  10.3  475  7.49  0.74  0.88  10.56  0.45  7.36  1.87  10.63  0.63
#
#          OM  Fertility
# 0    1.2040          0
# ...

# %%
#drop outliers
imputer=CustomImputer()
df=imputer.fit_transform(df)

# %%
df
# Out:
#        N     P    K    pH    EC    OC      S    Zn    Fe    Cu     Mn     B  \
# 0    138   8.6  560  7.46  0.62  0.70   5.90  0.24  0.31  0.77   8.71  0.11
# 20   245   8.1  560  7.31  0.63  0.78  11.60  0.29  0.43  0.57   7.73  0.74
# 29   245   8.3  560  7.58  0.74  0.83   8.20  0.32  0.96  1.57   2.67  0.59
# 42   182  10.7  708  7.48  0.57  1.11  14.20  0.59  0.92  1.15   6.69  0.65
# 51   107   8.3  612  7.43  0.43  0.75   7.20  0.18  0.95  0.89   2.16  0.74
# ..   ...   ...  ...   ...   ...   ...    ...   ...   ...   ...    ...   ...
# 878  351  10.7  623  7.96  0.51  0.29   7.24  0.36  4.69  0.69  11.03  0.69
# 879  264   9.0  486  7.24  0.47  0.10   3.92  0.35  8.26  0.45   7.98  0.40
# 880  276   9.2  370  7.62  0.62  0.49   6.64  0.42  3.57  0.63   6.48  0.32
# 881  320  13.8  391  7.38  0.65  1.07   5.43  0.58  4.58  1.02  13.25  0.53
# 882  264  10.3  475  7.49  0.74  0.88  10.56  0.45  7.36  1.87  10.63  0.63
#
#          OM  Fertility
# 0    1.2040          0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 622 entries, 0 to 882
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   N          622 non-null    int64
#  1   P          622 non-null    float64
#  2   K          622 non-null    int64
#  3   pH         622 non-null    float64
#  4   EC         622 non-null    float64
#  5   OC         622 non-null    float64
#  6   S          622 non-null    float64
#  7   Zn         622 non-null    float64
#  8   Fe         622 non-null    float64
#  9   Cu         622 non-null    float64
#  10  Mn         622 non-null    float64
#  11  B          622 non-null    float64
#  12  OM         622 non-null    float64
#  13  Fertility  622 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 72.9 KB

# %%
from matplotlib import pyplot as plt
import seaborn as sns
sns.set()
